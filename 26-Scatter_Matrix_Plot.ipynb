# %% [markdown]
# * 튜토리얼 영상링크 : https://youtu.be/PtSofOihtZs
# # Scatter Matrix Plot
# * https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html#plotting-tools

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl

# Jupyter Notebook 에 그래프 표시를 위해
# %matplotlib inline

# 한글폰트 사용시 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

# %%
from pandas.plotting import scatter_matrix
df = pd.DataFrame(np.random.randn(1000, 4), columns=['a', 'b', 'c', 'd'])
df.head()
# Out:
#           a         b         c         d
# 0  0.082438 -0.036313 -0.641197 -1.325368
# 1  0.260638  2.434821 -0.934626 -0.574908
# 2  0.382322  1.640532  1.304820 -1.433978
# 3 -0.893703  1.486142  0.525698 -2.487957
# 4  0.438842 -0.324942  1.266646 -0.125954

# %%
# kde - 커널밀도함수
scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x111fe3550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112056320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112091320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1120c8320>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1120d0630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1120d0908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11215de10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11217f6a0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1121d3da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1123137f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11234b7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112382cc0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1123c6240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1123ede10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1124297f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112461860>]],
#       dtype=object)
